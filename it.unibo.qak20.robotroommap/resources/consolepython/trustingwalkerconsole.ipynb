# %% [markdown]
# ## Command console for the trustingwalker

# %%
##############################################################
# trustingwalkerconsole.py
# ACTIVATE it.unibo.qak20.robotroommap\src\it\unibo\ctxtrustingwalker\MainCtxtrustingwalker.kt
##############################################################

import paho.mqtt.client as paho

### brokerAddr ="broker.hiqvemq.com"
brokerAddr ="localhost"

#define callback
def on_message(client, userdata, message):
    print("received message =",str(message.payload.decode("utf-8")))

def requestMovecell( x,y ):
    msg = "msg(movetoCell,request,py,trustingwalker,movetoCell("+x+","+y+"),1)"
    client.publish("unibo/qak/trustingwalker",msg) 
    print("requestMovecell done:" , msg  )

def console() :  
    print("console  STARTS :"   )
    cmd =  str( input() )
    while( cmd != "q"  ) :
        values = cmd.split(",")  ## ["6","3"]
        ## print( values[0] )
        requestMovecell( values[0],values[1] )
        cmd = str(input() )             

##################################################################

client= paho.Client("pyconsole")  
client.on_message=on_message            # Bind function to callback    

client.connect(brokerAddr)              #connect
print("connected to broker ", brokerAddr)

print("subscribing to unibo/polar")
client.subscribe("unibo/polar")      #subscribe

print("starting the client loop to receive sonar data" )
client.loop_start()                  #start loop to process received messages
 
console()
# Out:
# connected to broker  localhost
# subscribing to unibo/polar
# starting the client loop to receive sonar data
# console  STARTS :
# 6,3
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(6,3),1)
# received message = msg(polar,event,envsonarhandler,none,polar(30,180),1040)
# 0,2
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(0,2),1)
# 3,3
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(3,3),1)
# 0,5
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(0,5),1)
# 0,4
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(0,4),1)
# 4,1
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(4,1),1)
# received message = msg(polar,event,envsonarhandler,none,polar(30,180),1224)
# received message = msg(polar,event,envsonarhandler,none,polar(29,180),1233)
# received message = msg(polar,event,envsonarhandler,none,polar(24,180),1242)
# received message = msg(polar,event,envsonarhandler,none,polar(19,180),1251)
# received message = msg(polar,event,envsonarhandler,none,polar(14,180),1260)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1267)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1269)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1271)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1273)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1275)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1277)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1279)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1281)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1283)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1285)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1287)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1289)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1291)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1293)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1295)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1297)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1299)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1301)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1303)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1305)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1307)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1309)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1311)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1313)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1315)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1317)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1319)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1321)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1323)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1325)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1327)
# received message = msg(polar,event,envsonarhandler,none,polar(11,180),1329)
# 4,2
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(4,2),1)
# 5,1
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(5,1),1)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1347)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1354)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1356)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1358)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1360)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1362)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1364)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1366)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1368)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1370)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1372)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1374)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1376)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1378)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1380)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1382)
# 6,1
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(6,1),1)
# received message = msg(polar,event,envsonarhandler,none,polar(7,180),1384)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1393)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1395)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1397)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1399)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1401)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1403)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1405)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1407)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1409)
# 0,0
# requestMovecell done: msg(movetoCell,request,py,trustingwalker,movetoCell(0,0),1)
# received message = msg(polar,event,envsonarhandler,none,polar(2,180),1411)
